# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("../Weather_Database/WeatherPy_database.csv")
city_data_df.head()
# Out:
#    City_ID        City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0  Bredasdorp      ZA -34.5322   20.0403     54.45        84
# 1        1   Saskylakh      RU  71.9167  114.0833     43.47        79
# 2        2   Busselton      AU -33.6500  115.3333     50.77        85
# 3        3        Bara      NG  10.3744   10.7288     75.09        77
# 4        4       Vaini      TO -21.2000 -175.2000     75.36        88
#
#    Cloudiness  Wind Speed      Description
# 0         100        2.19  overcast clouds
# 1         100       13.22  overcast clouds
# 2           0        7.85        clear sky
# 3         100        4.27  overcast clouds
# 4          75       10.36    broken clouds

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
city_input_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & (city_data_df["Max Temp"] >= min_temp)]
city_input_df.head(40)
# Out:
#      City_ID                    City Country      Lat       Lng  Max Temp  \
# 3          3                    Bara      NG  10.3744   10.7288     75.09
# 4          4                   Vaini      TO -21.2000 -175.2000     75.36
# 10        10                  Faanui      PF -16.4833 -151.7500     76.73
# 12        12                Bac Lieu      VN   9.2850  105.7244     79.45
# 14        14              Hambantota      LK   6.1241   81.1185     78.73
# 18        18                  Albany      US  42.6001  -73.9662     78.26
# 20        20                  Broome      US  42.2506  -75.8330     78.15
# 22        22            Komsomolskiy      UZ  40.4272   71.7189     81.32
# 24        24              Georgetown      MY   5.4112  100.3354     82.33
# 26        26            Rive-De-Gier      FR  45.5307    4.6213     82.33
# 31        31                 Wanning      CN  18.8003  110.3967     81.90
# 38        38                 Kavieng      PG  -2.5744  150.7967     82.29
# 39        39               Ierapetra      GR  35.0100   25.7353     82.15
# 42        42                    Nara      JP  34.6851  135.8049     79.50
# 50        50                 Nanning      CN  22.8167  108.3167     82.85
# 53        53            Puerto Ayora      EC  -0.7393  -90.3518     76.96
# 55        55          Guerrero Negro      MX  27.9769 -114.0611     83.23
# 56        56                  Najran      SA  17.4924   44.1277     88.45
# 58        58                 Sibolga      ID   1.7427   98.7792     77.13
# 61        61                Barahona      DO  18.2085  -71.1008     89.42
# 62        62                Meulaboh      ID   4.1363   96.1285     75.61
# 64        64                  Bethel      US  41.3712  -73.4140     78.89
# 67        67                  Mizdah      LY  31.4451   12.9801     78.37
# 70        70                   Kapaa      US  22.0752 -159.3190     82.72
# 73        73                Nichinan      JP  31.6000  131.3667     80.58
# 85        85              Butaritari      KI   3.0707  172.7902     82.35
# 88        88  San Antonio Ilotenango      GT  15.0547  -91.2297     77.11
# 90        90                   Akyab      MM  20.1500   92.9000     81.91
# 91        91                  Atuona      PF  -9.8000 -139.0333     77.29
# 98        98                    Aksu      CN  41.1231   80.2644     80.15
# 101      101                  Lethem      GY   3.3803  -59.7968     83.39
# 104      104              Diamantino      BR -14.4086  -56.4461     87.49
# 109      109                  Padang      ID  -0.9492  100.3543     76.44
# 121      121                    Cody      US  44.5263 -109.0565     89.40
# 122      122    Chalons-En-Champagne      FR  48.9539    4.3672     81.63
# 123      123             Andros Town      BS  24.7000  -77.7667     89.56
# 133      133                   Buala      SB  -8.1450  159.5921     81.61
# 135      135                Acapulco      MX  16.8634  -99.8901     85.82
# 136      136                  Barmer      IN  25.7500   71.3833     86.20
# 139      139                   Kieta      PG  -6.2167  155.6333     79.36
#
#      Humidity  Cloudiness  Wind Speed           Description
# 3          77         100        4.27       overcast clouds
# 4          88          75       10.36         broken clouds
# 10         67          86        8.05       overcast clouds
# 12         87         100        6.96       overcast clouds
# 14         82          50       14.41      scattered clouds
# 18         85         100        1.99       overcast clouds
# 20         82          40       14.97      scattered clouds
# 22         26           0       11.50             clear sky
# 24         89          40        0.00      scattered clouds
# 26         40           0        2.51             clear sky
# 31         91          98        9.33       overcast clouds
# 38         77         100       12.10       overcast clouds
# 39         36           0       17.00             clear sky
# 42         85         100        1.92            light rain
# 50         92          95        9.13       overcast clouds
# 53         88          97        5.99       overcast clouds
# 55         46           4       11.90             clear sky
# 56         35         100        5.64       overcast clouds
# 58         84          98        2.91       overcast clouds
# 61         70          20       16.11            few clouds
# 62         87          87        4.54       overcast clouds
# 64         91          75       11.50  heavy intensity rain
# 67         41           0       16.62             clear sky
# 70         76          75       19.57         broken clouds
# 73         88         100       11.74            light rain
# 85         77           7       18.32             clear sky
# 88         45          71        9.08         broken clouds
# 90         83         100        1.14       overcast clouds
# 91         70          40       16.26      scattered clouds
# 98         25           6        5.48             clear sky
# 101        76          90        3.38       overcast clouds
# 104        22           5        4.07             clear sky
# 109        77          11        3.60            few clouds
# 121        25           0       23.02             clear sky
# 122        29           5        8.25             clear sky
# 123        66          86       13.24       overcast clouds
# 133        73          31        5.37      scattered clouds
# 135        74         100        9.22       overcast clouds
# 136        66         100        8.86       overcast clouds
# 139        79          45        3.20      scattered clouds

# %%
# 4a. Determine if there are any empty rows.
city_input_df.isnull().count()
# Out:
# City_ID        243
# City           243
# Country        243
# Lat            243
# Lng            243
# Max Temp       243
# Humidity       243
# Cloudiness     243
# Wind Speed     243
# Description    243
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_df = city_input_df.dropna()
clean_df.count()
# Out:
# City_ID        243
# City           243
# Country        243
# Lat            243
# Lng            243
# Max Temp       243
# Humidity       243
# Cloudiness     243
# Wind Speed     243
# Description    243
# dtype: int64

# %%
import numpy as np 
import ipywidgets as widgets 

# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_df[["City", "Country", "Max Temp", "Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df
# Out:
#              City Country  Max Temp       Description      Lat       Lng  \
# 3            Bara      NG     75.09   overcast clouds  10.3744   10.7288
# 4           Vaini      TO     75.36     broken clouds -21.2000 -175.2000
# 10         Faanui      PF     76.73   overcast clouds -16.4833 -151.7500
# 12       Bac Lieu      VN     79.45   overcast clouds   9.2850  105.7244
# 14     Hambantota      LK     78.73  scattered clouds   6.1241   81.1185
# ..            ...     ...       ...               ...      ...       ...
# 690     Matehuala      MX     87.01         clear sky  23.6500 -100.6500
# 691  Marsa Matruh      EG     76.98         clear sky  31.3525   27.2453
# 696  Ansermanuevo      CO     83.17        few clouds   4.7972  -75.9950
# 698     Flin Flon      CA     84.04             smoke  54.7682 -101.8650
# 700        Japura      ID     75.22        few clouds  -0.3167  102.3500
#
#     Hotel Name
# 3
# 4
# 10
# 12
# 14
# ..         ...
# 690
# 691
# 696
# 698
# 700
#
# [243 rows x 7 columns]

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.
for index,row in hotel_df.iterrows():

    # 6c. Get latitude and longitude from DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    params["location"] = f"{lat},{lng}"
    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # 6e. Make request and retrieve the JSON data from the search. 
    hotels = requests.get(base_url, params=params).json()
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found....skipping")
# Out:
# Hotel not found....skipping
# Hotel not found....skipping
# Hotel not found....skipping
# Hotel not found....skipping
# Hotel not found....skipping
# Hotel not found....skipping
# Hotel not found....skipping
# Hotel not found....skipping
# Hotel not found....skipping

# %%
hotel_df.head(35)
# Out:
#                        City Country  Max Temp           Description      Lat  \
# 3                      Bara      NG     75.09       overcast clouds  10.3744
# 4                     Vaini      TO     75.36         broken clouds -21.2000
# 10                   Faanui      PF     76.73       overcast clouds -16.4833
# 12                 Bac Lieu      VN     79.45       overcast clouds   9.2850
# 14               Hambantota      LK     78.73      scattered clouds   6.1241
# 18                   Albany      US     78.26       overcast clouds  42.6001
# 20                   Broome      US     78.15      scattered clouds  42.2506
# 22             Komsomolskiy      UZ     81.32             clear sky  40.4272
# 24               Georgetown      MY     82.33      scattered clouds   5.4112
# 26             Rive-De-Gier      FR     82.33             clear sky  45.5307
# 31                  Wanning      CN     81.90       overcast clouds  18.8003
# 38                  Kavieng      PG     82.29       overcast clouds  -2.5744
# 39                Ierapetra      GR     82.15             clear sky  35.0100
# 42                     Nara      JP     79.50            light rain  34.6851
# 50                  Nanning      CN     82.85       overcast clouds  22.8167
# 53             Puerto Ayora      EC     76.96       overcast clouds  -0.7393
# 55           Guerrero Negro      MX     83.23             clear sky  27.9769
# 56                   Najran      SA     88.45       overcast clouds  17.4924
# 58                  Sibolga      ID     77.13       overcast clouds   1.7427
# 61                 Barahona      DO     89.42            few clouds  18.2085
# 62                 Meulaboh      ID     75.61       overcast clouds   4.1363
# 64                   Bethel      US     78.89  heavy intensity rain  41.3712
# 67                   Mizdah      LY     78.37             clear sky  31.4451
# 70                    Kapaa      US     82.72         broken clouds  22.0752
# 73                 Nichinan      JP     80.58            light rain  31.6000
# 85               Butaritari      KI     82.35             clear sky   3.0707
# 88   San Antonio Ilotenango      GT     77.11         broken clouds  15.0547
# 90                    Akyab      MM     81.91       overcast clouds  20.1500
# 91                   Atuona      PF     77.29      scattered clouds  -9.8000
# 98                     Aksu      CN     80.15             clear sky  41.1231
# 101                  Lethem      GY     83.39       overcast clouds   3.3803
# 104              Diamantino      BR     87.49             clear sky -14.4086
# 109                  Padang      ID     76.44            few clouds  -0.9492
# 121                    Cody      US     89.40             clear sky  44.5263
# 122    Chalons-En-Champagne      FR     81.63             clear sky  48.9539
#
#           Lng                                         Hotel Name
# 3     10.7288
# 4   -175.2000                                Keleti Beach Resort
# 10  -151.7500                 Bora-Bora Pearl Beach Resort & Spa
# 12   105.7244                         Khách sạn Sài Gòn Bạc Liêu
# 14    81.1185                                        Bungalow 63
# 18   -73.9662
# 20   -75.8330                         Chenango Valley State Park
# 22    71.7189                                          Ikathouse
# 24   100.3354                                     Cititel Penang
# 26     4.6213                                       B&B Ebeniste
# 31   110.3967                                     Paradise Hotel
# 38   150.7967                                Nusa Island Retreat
# 39    25.7353  Cretan Villa Hotel & Apartments in Ierapetra C...
# 42   135.8049                            Guesthouse Nara Komachi
# 50   108.3167                     Nanning Travelling With Hostel
# 53   -90.3518                          Finch Bay Galapagos Hotel
# 55  -114.0611                       Casa Laguna, Bed & Breakfast
# 56    44.1277                                  محمد هادي ال فطيح
# 58    98.7792                        Hotel Syariah CN Darussalam
# 61   -71.1008                                       Hotel Caribe
# 62    96.1285                                          Kost Pria
# 64   -73.4140                      Courtyard by Marriott Danbury
# 67    12.9801                                محمدالمبروك الاريقط
# 70  -159.3190                Sheraton Kauai Coconut Beach Resort
# 73   131.3667                                    Guest House Aki
# 85   172.7902                                 Isles Sunset Lodge
# 88   -91.2297    Servicio de taxi San Antonio Ilotenango, QUICHE
# 90    92.9000                                       Hotel Memory
# 91  -139.0333                                        Villa Enata
# 98    80.2644                               Pudong Holiday Hotel
# 101  -59.7968                                       Savannah Inn
# 104  -56.4461                                        Hotel Delta
# 109  100.3543                                     Mercure Padang
# 121 -109.0565  Holiday Inn Cody-at Buffalo Bill Village, an I...
# 122    4.3672                                 Hotel D'Angleterre

# %%
# Insert 'NaN' into empty 'hotel name' cells
hotel_df.loc[hotel_df["Hotel Name"] == ''] = np.nan

# %%
# 7. Drop the rows where there is no Hotel Name.
hotel_df.head(35)
# Out:
#                        City Country  Max Temp           Description      Lat  \
# 3                       NaN     NaN       NaN                   NaN      NaN
# 4                     Vaini      TO     75.36         broken clouds -21.2000
# 10                   Faanui      PF     76.73       overcast clouds -16.4833
# 12                 Bac Lieu      VN     79.45       overcast clouds   9.2850
# 14               Hambantota      LK     78.73      scattered clouds   6.1241
# 18                      NaN     NaN       NaN                   NaN      NaN
# 20                   Broome      US     78.15      scattered clouds  42.2506
# 22             Komsomolskiy      UZ     81.32             clear sky  40.4272
# 24               Georgetown      MY     82.33      scattered clouds   5.4112
# 26             Rive-De-Gier      FR     82.33             clear sky  45.5307
# 31                  Wanning      CN     81.90       overcast clouds  18.8003
# 38                  Kavieng      PG     82.29       overcast clouds  -2.5744
# 39                Ierapetra      GR     82.15             clear sky  35.0100
# 42                     Nara      JP     79.50            light rain  34.6851
# 50                  Nanning      CN     82.85       overcast clouds  22.8167
# 53             Puerto Ayora      EC     76.96       overcast clouds  -0.7393
# 55           Guerrero Negro      MX     83.23             clear sky  27.9769
# 56                   Najran      SA     88.45       overcast clouds  17.4924
# 58                  Sibolga      ID     77.13       overcast clouds   1.7427
# 61                 Barahona      DO     89.42            few clouds  18.2085
# 62                 Meulaboh      ID     75.61       overcast clouds   4.1363
# 64                   Bethel      US     78.89  heavy intensity rain  41.3712
# 67                   Mizdah      LY     78.37             clear sky  31.4451
# 70                    Kapaa      US     82.72         broken clouds  22.0752
# 73                 Nichinan      JP     80.58            light rain  31.6000
# 85               Butaritari      KI     82.35             clear sky   3.0707
# 88   San Antonio Ilotenango      GT     77.11         broken clouds  15.0547
# 90                    Akyab      MM     81.91       overcast clouds  20.1500
# 91                   Atuona      PF     77.29      scattered clouds  -9.8000
# 98                     Aksu      CN     80.15             clear sky  41.1231
# 101                  Lethem      GY     83.39       overcast clouds   3.3803
# 104              Diamantino      BR     87.49             clear sky -14.4086
# 109                  Padang      ID     76.44            few clouds  -0.9492
# 121                    Cody      US     89.40             clear sky  44.5263
# 122    Chalons-En-Champagne      FR     81.63             clear sky  48.9539
#
#           Lng                                         Hotel Name
# 3         NaN                                                NaN
# 4   -175.2000                                Keleti Beach Resort
# 10  -151.7500                 Bora-Bora Pearl Beach Resort & Spa
# 12   105.7244                         Khách sạn Sài Gòn Bạc Liêu
# 14    81.1185                                        Bungalow 63
# 18        NaN                                                NaN
# 20   -75.8330                         Chenango Valley State Park
# 22    71.7189                                          Ikathouse
# 24   100.3354                                     Cititel Penang
# 26     4.6213                                       B&B Ebeniste
# 31   110.3967                                     Paradise Hotel
# 38   150.7967                                Nusa Island Retreat
# 39    25.7353  Cretan Villa Hotel & Apartments in Ierapetra C...
# 42   135.8049                            Guesthouse Nara Komachi
# 50   108.3167                     Nanning Travelling With Hostel
# 53   -90.3518                          Finch Bay Galapagos Hotel
# 55  -114.0611                       Casa Laguna, Bed & Breakfast
# 56    44.1277                                  محمد هادي ال فطيح
# 58    98.7792                        Hotel Syariah CN Darussalam
# 61   -71.1008                                       Hotel Caribe
# 62    96.1285                                          Kost Pria
# 64   -73.4140                      Courtyard by Marriott Danbury
# 67    12.9801                                محمدالمبروك الاريقط
# 70  -159.3190                Sheraton Kauai Coconut Beach Resort
# 73   131.3667                                    Guest House Aki
# 85   172.7902                                 Isles Sunset Lodge
# 88   -91.2297    Servicio de taxi San Antonio Ilotenango, QUICHE
# 90    92.9000                                       Hotel Memory
# 91  -139.0333                                        Villa Enata
# 98    80.2644                               Pudong Holiday Hotel
# 101  -59.7968                                       Savannah Inn
# 104  -56.4461                                        Hotel Delta
# 109  100.3543                                     Mercure Padang
# 121 -109.0565  Holiday Inn Cody-at Buffalo Bill Village, an I...
# 122    4.3672                                 Hotel D'Angleterre

# %%
clean_hotel_df = hotel_df.dropna()
clean_hotel_df.head(35)
# Out:
#                        City Country  Max Temp           Description      Lat  \
# 4                     Vaini      TO     75.36         broken clouds -21.2000
# 10                   Faanui      PF     76.73       overcast clouds -16.4833
# 12                 Bac Lieu      VN     79.45       overcast clouds   9.2850
# 14               Hambantota      LK     78.73      scattered clouds   6.1241
# 20                   Broome      US     78.15      scattered clouds  42.2506
# 22             Komsomolskiy      UZ     81.32             clear sky  40.4272
# 24               Georgetown      MY     82.33      scattered clouds   5.4112
# 26             Rive-De-Gier      FR     82.33             clear sky  45.5307
# 31                  Wanning      CN     81.90       overcast clouds  18.8003
# 38                  Kavieng      PG     82.29       overcast clouds  -2.5744
# 39                Ierapetra      GR     82.15             clear sky  35.0100
# 42                     Nara      JP     79.50            light rain  34.6851
# 50                  Nanning      CN     82.85       overcast clouds  22.8167
# 53             Puerto Ayora      EC     76.96       overcast clouds  -0.7393
# 55           Guerrero Negro      MX     83.23             clear sky  27.9769
# 56                   Najran      SA     88.45       overcast clouds  17.4924
# 58                  Sibolga      ID     77.13       overcast clouds   1.7427
# 61                 Barahona      DO     89.42            few clouds  18.2085
# 62                 Meulaboh      ID     75.61       overcast clouds   4.1363
# 64                   Bethel      US     78.89  heavy intensity rain  41.3712
# 67                   Mizdah      LY     78.37             clear sky  31.4451
# 70                    Kapaa      US     82.72         broken clouds  22.0752
# 73                 Nichinan      JP     80.58            light rain  31.6000
# 85               Butaritari      KI     82.35             clear sky   3.0707
# 88   San Antonio Ilotenango      GT     77.11         broken clouds  15.0547
# 90                    Akyab      MM     81.91       overcast clouds  20.1500
# 91                   Atuona      PF     77.29      scattered clouds  -9.8000
# 98                     Aksu      CN     80.15             clear sky  41.1231
# 101                  Lethem      GY     83.39       overcast clouds   3.3803
# 104              Diamantino      BR     87.49             clear sky -14.4086
# 109                  Padang      ID     76.44            few clouds  -0.9492
# 121                    Cody      US     89.40             clear sky  44.5263
# 122    Chalons-En-Champagne      FR     81.63             clear sky  48.9539
# 123             Andros Town      BS     89.56       overcast clouds  24.7000
# 133                   Buala      SB     81.61      scattered clouds  -8.1450
#
#           Lng                                         Hotel Name
# 4   -175.2000                                Keleti Beach Resort
# 10  -151.7500                 Bora-Bora Pearl Beach Resort & Spa
# 12   105.7244                         Khách sạn Sài Gòn Bạc Liêu
# 14    81.1185                                        Bungalow 63
# 20   -75.8330                         Chenango Valley State Park
# 22    71.7189                                          Ikathouse
# 24   100.3354                                     Cititel Penang
# 26     4.6213                                       B&B Ebeniste
# 31   110.3967                                     Paradise Hotel
# 38   150.7967                                Nusa Island Retreat
# 39    25.7353  Cretan Villa Hotel & Apartments in Ierapetra C...
# 42   135.8049                            Guesthouse Nara Komachi
# 50   108.3167                     Nanning Travelling With Hostel
# 53   -90.3518                          Finch Bay Galapagos Hotel
# 55  -114.0611                       Casa Laguna, Bed & Breakfast
# 56    44.1277                                  محمد هادي ال فطيح
# 58    98.7792                        Hotel Syariah CN Darussalam
# 61   -71.1008                                       Hotel Caribe
# 62    96.1285                                          Kost Pria
# 64   -73.4140                      Courtyard by Marriott Danbury
# 67    12.9801                                محمدالمبروك الاريقط
# 70  -159.3190                Sheraton Kauai Coconut Beach Resort
# 73   131.3667                                    Guest House Aki
# 85   172.7902                                 Isles Sunset Lodge
# 88   -91.2297    Servicio de taxi San Antonio Ilotenango, QUICHE
# 90    92.9000                                       Hotel Memory
# 91  -139.0333                                        Villa Enata
# 98    80.2644                               Pudong Holiday Hotel
# 101  -59.7968                                       Savannah Inn
# 104  -56.4461                                        Hotel Delta
# 109  100.3543                                     Mercure Padang
# 121 -109.0565  Holiday Inn Cody-at Buffalo Bill Village, an I...
# 122    4.3672                                 Hotel D'Angleterre
# 123  -77.7667                                        Hanks place
# 133  159.5921                               Maringe Lagoon Lodge

# %%
hotel_df.count()
# Out:
# City           234
# Country        234
# Max Temp       234
# Description    234
# Lat            234
# Lng            234
# Hotel Name     234
# dtype: int64

# %%
# 8a. Create the output File (CSV)
output_data_file = "../Vacation_Search/WeatherPy_vacation.csv"

# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature 
# for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Description} and {Max Temp} °F</dd>
</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 
locations = clean_hotel_df[["Lat", "Lng"]]
max_temp = clean_hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
